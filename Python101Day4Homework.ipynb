# %%
import os
import pandas as pd
import numpy as np

# %%
#https://raw.githubusercontent.com/vikrambj2019/basic/master/Data/auto-mpg.csv
path = 'https://raw.githubusercontent.com/vikrambj2019/basic/master/Data/'
filename_read=os.path.join(path,'auto-mpg.csv')
df=pd.read_csv(filename_read,na_values=['NA','?'])

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 393  27.0          4         140.0        86.0    2790          15.6    82
# 394  44.0          4          97.0        52.0    2130          24.6    82
# 395  32.0          4         135.0        84.0    2295          11.6    82
# 396  28.0          4         120.0        79.0    2625          18.6    82
# 397  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin             name
# 393       1  ford mustang gl
# 394       2        vw pickup
# 395       1    dodge rampage
# 396       1      ford ranger
# 397       1       chevy s-10

# %%
df['mpg'].head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
df.iloc[10]
# Out:
# mpg                              15
# cylinders                         8
# displacement                    383
# horsepower                      170
# weight                         3563
# acceleration                     10
# year                             70
# origin                            1
# name            dodge challenger se
# Name: 10, dtype: object

# %%
#this allows you to save a dataframe as an Excel file to your computer!!!
df.to_excel('test.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# year            398 non-null int64
# origin          398 non-null int64
# name            398 non-null object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
#df.apply(pd.Series.value_counts)

# %%
pd.isnull(df)
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration   year  \
# 0    False      False         False       False   False         False  False
# 1    False      False         False       False   False         False  False
# 2    False      False         False       False   False         False  False
# 3    False      False         False       False   False         False  False
# 4    False      False         False       False   False         False  False
# 5    False      False         False       False   False         False  False
# 6    False      False         False       False   False         False  False
# 7    False      False         False       False   False         False  False
# 8    False      False         False       False   False         False  False
# 9    False      False         False       False   False         False  False
# 10   False      False         False       False   False         False  False
# ...

# %%
df.replace([1,3],['one','three'])
# Out:
#       mpg cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0         8         307.0       130.0    3504          12.0    70
# 1    15.0         8         350.0       165.0    3693          11.5    70
# 2    18.0         8         318.0       150.0    3436          11.0    70
# 3    16.0         8         304.0       150.0    3433          12.0    70
# 4    17.0         8         302.0       140.0    3449          10.5    70
# 5    15.0         8         429.0       198.0    4341          10.0    70
# 6    14.0         8         454.0       220.0    4354           9.0    70
# 7    14.0         8         440.0       215.0    4312           8.5    70
# 8    14.0         8         455.0       225.0    4425          10.0    70
# 9    15.0         8         390.0       190.0    3850           8.5    70
# 10   15.0         8         383.0       170.0    3563          10.0    70
# 11   14.0         8         340.0       160.0    3609           8.0    70
# ...

# %%
df['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
df.groupby('cylinders')['mpg'].mean()
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
df.groupby('year')['weight'].mean()
# Out:
# year
# 70    3372.793103
# 71    2995.428571
# 72    3237.714286
# 73    3419.025000
# 74    2877.925926
# 75    3176.800000
# 76    3078.735294
# 77    2997.357143
# 78    2861.805556
# 79    3055.344828
# 80    2436.655172
# 81    2522.931034
# 82    2453.548387
# Name: weight, dtype: float64

# %%
df.groupby('cylinders').agg(np.mean)
# Out:
#                  mpg  displacement  horsepower       weight  acceleration  \
# cylinders
# 3          20.550000     72.500000   99.250000  2398.500000     13.250000
# 4          29.286765    109.796569   78.281407  2308.127451     16.601471
# 5          27.366667    145.000000   82.333333  3103.333333     18.633333
# 6          19.985714    218.142857  101.506024  3198.226190     16.263095
# 8          14.963107    345.009709  158.300971  4114.718447     12.955340
#
#                 year    origin
# cylinders
# 3          75.500000  3.000000
# 4          77.073529  1.985294
# 5          79.000000  2.000000
# 6          75.928571  1.190476
# 8          73.902913  1.000000

# %%
df.groupby('cylinders').agg(np.max)
# Out:
#             mpg  displacement  horsepower  weight  acceleration  year  origin  \
# cylinders
# 3          23.7          80.0       110.0    2720          13.5    80       3
# 4          46.6         156.0       115.0    3270          24.8    82       3
# 5          36.4         183.0       103.0    3530          20.1    80       2
# 6          38.0         262.0       165.0    3907          21.0    82       3
# 8          26.6         455.0       230.0    5140          22.2    81       1
#
#                           name
# cylinders
# 3              mazda rx2 coupe
# 4             vw rabbit custom
# 5           mercedes benz 300d
# 6                 volvo diesel
# 8          pontiac safari (sw)

# %%
df.apply(np.max)
# Out:
# mpg                         46.6
# cylinders                      8
# displacement                 455
# horsepower                   230
# weight                      5140
# acceleration                24.8
# year                          82
# origin                         3
# name            vw rabbit custom
# dtype: object

# %%
df.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# year          0.579267  -0.348746     -0.370164   -0.416361 -0.306564
# origin        0.563450  -0.562543     -0.609409   -0.455171 -0.581024
#
#               acceleration      year    origin
# mpg               0.420289  0.579267  0.563450
# cylinders        -0.505419 -0.348746 -0.562543
# displacement     -0.543684 -0.370164 -0.609409
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.417457 -0.306564 -0.581024
# acceleration      1.000000  0.288137  0.205873
# ...

# %%
df.mean()
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# horsepower       104.469388
# weight          2970.424623
# acceleration      15.568090
# year              76.010050
# origin             1.572864
# dtype: float64

# %%
df.std()
# Out:
# mpg               7.815984
# cylinders         1.701004
# displacement    104.269838
# horsepower       38.491160
# weight          846.841774
# acceleration      2.757689
# year              3.697627
# origin            0.802055
# dtype: float64

# %%
df.count()
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      392
# weight          398
# acceleration    398
# year            398
# origin          398
# name            398
# dtype: int64

# %%
df1 = df.append(df)

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df1.count()
# Out:
# mpg             796
# cylinders       796
# displacement    796
# horsepower      784
# weight          796
# acceleration    796
# year            796
# origin          796
# name            796
# dtype: int64

# %%
df.count()
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      392
# weight          398
# acceleration    398
# year            398
# origin          398
# name            398
# dtype: int64

# %%
df.groupby(['cylinders','origin'])['horsepower'].transform('mean').unique()
# Out:
# array([158.30097087,  75.57971014,  99.67123288,  78.31147541,
#         80.95652174,  99.25      , 115.83333333, 113.5       ,
#         82.33333333])

# %%
df['horsepower']=df['horsepower'].fillna(df.groupby(['cylinders','origin'])['horsepower'].transform('mean'))

# %%
df.count()
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# year            398
# origin          398
# name            398
# dtype: int64

# %%
df2 = pd.DataFrame(df.groupby(['cylinders'])['horsepower'].aggregate('mean'))

# %%
df2.head()

columns_needs = ['mpg','cylinders']

# %%
result=pd.merge(df[columns_needs],df2,how='left',left_on=['cylinders'],right_on=['cylinders'])

# %%
result.head()
# Out:
#     mpg  cylinders  horsepower
# 0  18.0          8  158.300971
# 1  15.0          8  158.300971
# 2  18.0          8  158.300971
# 3  16.0          8  158.300971
# 4  17.0          8  158.300971
